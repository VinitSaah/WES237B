# %%
from PIL import Image
im = Image.open('image.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGBA size=650x434 at 0xB3F8AEC8>

# %%
im2 = Image.open('opencv_dct.tif')
im2
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0xB0955868>

# %%
im3 = Image.open('original_color.tif')
im3
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=650x434 at 0xB4FF5EB0>

# %%
im4 = Image.open('dct_lab_naive.tif')
im4
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0xB09555E0>

# %%
im5 = Image.open('dct_lab_opt.tif')
im5
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0xB3F8A9B8>
