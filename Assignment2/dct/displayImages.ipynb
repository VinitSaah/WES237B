# %%
from PIL import Image
im = Image.open('image.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=640x480 at 0xB4068AA8>

# %%
im2 = Image.open('opencv_dct.tif')
im2
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0xB4068328>

# %%
im3 = Image.open('original_color.tif')
im3
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=640x480 at 0xB0A1C9A0>

# %%
im4 = Image.open('dct_lab_naive.tif')
im4
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0xB0A1CCD0>

# %%
im5 = Image.open('dct_lab_opt.tif')
im5
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0xB0A1CC88>
