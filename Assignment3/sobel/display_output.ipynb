# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('./image_outputs/image_gray.tif')
imgplot = plt.imshow(img, cmap='gray')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-17a01911d49c> in <module>
#       2 import matplotlib.pyplot as plt
#       3 import matplotlib.image as mpimg
# ----> 4 img=mpimg.imread('./image_outputs/image_gray.tif')
#       5 imgplot = plt.imshow(img, cmap='gray')
#       6 plt.show()
#
# /usr/lib/python3/dist-packages/matplotlib/image.py in imread(fname, format)
#    1293             raise ValueError('Only know how to handle extensions: %s; '
#    1294                              'with Pillow installed matplotlib can handle '
# -> 1295                              'more images' % list(handlers))
#    1296         return im
#    1297
#
# ValueError: Only know how to handle extensions: ['png']; with Pillow installed matplotlib can handle more images

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('image_outputs/sobel_opencv.tif')
imgplot = plt.imshow(img, cmap='gray')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-f9fec001efba> in <module>
#       2 import matplotlib.pyplot as plt
#       3 import matplotlib.image as mpimg
# ----> 4 img=mpimg.imread('image_outputs/sobel_opencv.tif')
#       5 imgplot = plt.imshow(img, cmap='gray')
#       6 plt.show()
#
# /usr/lib/python3/dist-packages/matplotlib/image.py in imread(fname, format)
#    1293             raise ValueError('Only know how to handle extensions: %s; '
#    1294                              'with Pillow installed matplotlib can handle '
# -> 1295                              'more images' % list(handlers))
#    1296         return im
#    1297
#
# ValueError: Only know how to handle extensions: ['png']; with Pillow installed matplotlib can handle more images

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('image_outputs/sobel_naive.tif')
imgplot = plt.imshow(img, cmap='gray')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
