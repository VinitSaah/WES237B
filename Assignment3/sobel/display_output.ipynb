# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('./image_outputs/image_gray.tif')
imgplot = plt.imshow(img, cmap='gray')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('image_outputs/sobel_opencv.tif')
imgplot = plt.imshow(img, cmap='gray')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('image_outputs/sobel_naive.tif')
imgplot = plt.imshow(img, cmap='gray')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('image_outputs/sobel_unrolled.tif')
imgplot = plt.imshow(img, cmap='gray')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('image_outputs/sobel_neon.tif')
imgplot = plt.imshow(img, cmap='gray')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
