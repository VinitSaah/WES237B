# %%
from PIL import Image
im = Image.open('./image_outputs/image_gray.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=384x384 at 0x7F9D93DEB8>

# %%
from PIL import Image
im1 = Image.open('./image_outputs/sobel_opencv.tif')
im1
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=384x384 at 0x7F9D945278>

# %%
from PIL import Image
im2 = Image.open('./image_outputs/sobel_naive.tif')
im2
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=384x384 at 0x7F9D9455F8>

# %%
from PIL import Image
im3 = Image.open('./image_outputs/sobel_unrolled.tif')
im3
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=384x384 at 0x7F9D945978>

# %%
from PIL import Image
im4 = Image.open('./image_outputs/sobel_neon.tif')
im4
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=384x384 at 0x7F9D9557B8>
