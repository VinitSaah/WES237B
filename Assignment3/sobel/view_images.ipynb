# %%
from PIL import Image
im = Image.open('./image_outputs/image_gray.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=384x384 at 0x7F94160518>

# %%
from PIL import Image
im1 = Image.open('./image_outputs/sobel_opencv.tif')
im1
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=384x384 at 0x7F7F353EB8>

# %%
from PIL import Image
im2 = Image.open('./image_outputs/sobel_naive.tif')
im2
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=384x384 at 0x7F7F2E3320>

# %%
from PIL import Image
im3 = Image.open('./image_outputs/sobel_unrolled.tif')
im3
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=384x384 at 0x7F7F2EC908>
